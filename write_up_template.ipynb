# %%
# %matplotlib inline
# %matplotlib notebook

# %%
import matplotlib as mpl
import matplotlib.image as mpimg 
import matplotlib.pyplot as plt
import pandas as pd
from PIL import Image

# %% [markdown]
# # Project 1

# %% [markdown]
# # Dataset
#
# * Why we chose it?
# * Where it came from - API
# * Limitations
# * Clean Up

# %% [markdown]
# # Clean Up
# * list out the steps

# %%
final_df = pd.read_csv('moviesapi_clean.csv')
final_df.head()
# Out:
#                                       Title  Year  Rated  Runtime  \
# 0                                    Avatar  2009  PG-13      162
# 1  Pirates of the Caribbean: At World's End  2007  PG-13      169
# 2                                   Spectre  2015  PG-13      148
# 3                     The Dark Knight Rises  2012  PG-13      164
# 4                               John Carter  2012  PG-13      132
#
#                                 Genre           Director  \
# 0  Action, Adventure, Fantasy, Sci-Fi      James Cameron
# 1          Action, Adventure, Fantasy     Gore Verbinski
# 2         Action, Adventure, Thriller         Sam Mendes
# 3                    Action, Thriller  Christopher Nolan
# 4           Action, Adventure, Sci-Fi     Andrew Stanton
#
#                                               Writer  \
# 0                                      James Cameron
# 1  Ted Elliott, Terry Rossio, Ted Elliott (charac...
# 2  John Logan (screenplay by), Neal Purvis (scree...
# ...

# %%
mpl.rcParams['figure.dpi']= 1200

img  = Image.open('year_bubble.png')

plt.figure(figsize = (4,2))
plt.axis('off')
plt.imshow(img, aspect = 'equal')

# %% [markdown]
# # Revenue v. Budget
# * PG - Avg rev per decade
# * AR - bubble plot - Revenue by Year
# * AR - Budget over time (explanation for change in decade)
# * AR - Revenue v Budget stacked horizontal bar
# * AR - Popularity over time
# * VR - Budget v. Runtime

# %% [markdown]
# # Genre
# * PG - Frequency
# * VR - Genre v. Rating

# %% [markdown]
# # Language
# * SS - Frequency
# * SS - Count
# * SS - Production

# %% [markdown]
# # Countries
# * SS - Frequency

# %% [markdown]
# # Writers
# * SS - Count vs. movies
# * SS - Profit vs. writer count
# * SS - Avg IMDB rating v. count

# %% [markdown]
# # Oscar Winners
# * SS - Top 40

# %% [markdown]
# # Wordclouds (Frequency)
# * AR - Title
# * AR - Genre
# * AR - Country
# * AR - Spoken Language

# %% [markdown]
# # Conclusions
# *
# *
# *
